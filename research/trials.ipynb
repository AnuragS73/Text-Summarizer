# %%
def mult(x:int,y:int):
    return x*y

# %%
mult(3,4)
# Out:
# 12

# %%
mult(2,'3')
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def mult2(x:int,y:int):
    return x*y

# %%
mult2(2,'3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mult2(2,'3')
#
# File c:\Users\AnuragS\OneDrive\cv_project\Text Summarizer\venv\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function mult2 at 0x000001F6940872E0> does not match annotation type <class 'int'>
